# %% [markdown]
# # **DataFrame Exercise**

# %% [markdown]
# ## Part 1
# * Use pandas to read the `bestsellers` dataset into a DataFrame
# * Once you've done that, use Pandas to figure out how many rows and columns the DF has
# * Inspect the first 5 rows
# * Inspect the first 19 rows
# * Inspect the last 5 rows
# * Inspect the last 2 rows
# * Which columns (if any) are missing values?
# * What datatype did Pandas assign to "User Rating"?
# * How many integer columns are in the DataFrame?

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
datasets_path = '/content/drive/MyDrive/Dataset'
files = os.listdir(datasets_path)

for f in files:
    print(f)
# Out:
# Mounted at /content/drive
# kc_house_data.csv
# bands.csv
# movie_titles.tsv
# chess.csv
# countries of the world.csv
# crime.csv
# offense_codes.csv
# Salaries.csv
# pollution.csv
# bestsellers.csv
# JoeBidenTweets.csv
# world-happiness-report-2021.csv
# laliga.csv
# STEM_Salaries.csv
# nst-est2020.csv
# titanic.csv
# states.csv
# nuforc_reports.csv
# coin_Bitcoin.csv
# netflix_titles.csv
# billboard_charts.csv
# sales.csv
# game_stats.csv
# mount_everest_deaths.csv
# Pokemon.csv
# car_stocks.csv
# denver_crime.csv
# state_pops.csv
# insurance.csv
# Data.csv

# %%
def load_dataset(filename, base_dir='/content/drive/MyDrive/Dataset', **kwargs):
    from pathlib import Path
    import pandas as pd
    return pd.read_csv(Path(base_dir) / filename, **kwargs)

# %%
bestsellers = load_dataset('bestsellers.csv')

# %%
bestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %%
bestsellers.shape
# Out:
# (550, 7)

# %%
bestsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
bestsellers.head(19)
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
#      User Rating  Reviews  Price  Year        Genre
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
bestsellers.columns.isnull().sum()
# Out:
# np.int64(0)

# %%
bestsellers['User Rating'].dtypes
# Out:
# dtype('float64')

# %%
bestsellers.select_dtypes(include='int')
# Out:
#      Reviews  Price  Year
# 0      17350      8  2016
# 1       2052     22  2011
# 2      18979     15  2018
# 3      21424      6  2017
# 4       7665     12  2019
# ..       ...    ...   ...
# 545     9413      8  2019
# 546    14331      8  2016
# 547    14331      8  2017
# 548    14331      8  2018
# 549    14331      8  2019
#
# [550 rows x 3 columns]

# %% [markdown]
# ## Part 2
#
# * The `mount_everest_deaths` dataset has its own index column provided in the dataset.  When importing it, use the existing index column.
# * Which columns have zero null values?
# * Which column has the most null values?

# %%
deaths = load_dataset('mount_everest_deaths.csv', index_col=0)

# %%
deaths
# Out:
#                        Name          Date   Age  \
# No.
# 1                     Dorje  June 7, 1922   NaN
# 2                    Lhakpa  June 7, 1922   NaN
# 3                     Norbu  June 7, 1922   NaN
# 4                    Pasang  June 7, 1922   NaN
# 5                      Pema  June 7, 1922   NaN
# ..                      ...           ...   ...
# 306  Christopher Jon Kulish  May 27, 2019  62.0
# 307               Puwei Liu  May 12, 2021  55.0
# 308           Abdul Waraich  May 12, 2021  41.0
# 309      Pemba Tashi Sherpa  May 18, 2021  28.0
# 310      Wong Dorchi Sherpa  May 23, 2021   NaN
#
#                                 Expedition    Nationality  \
# No.
# 1    1922 British Mount Everest Expedition          Nepal
# 2    1922 British Mount Everest Expedition          Nepal
# 3    1922 British Mount Everest Expedition          Nepal
# 4    1922 British Mount Everest Expedition          Nepal
# 5    1922 British Mount Everest Expedition          Nepal
# ..                                     ...            ...
# 306             Climbing the Seven Summits  United States
# 307                     Seven Summit Treks  United States
# 308                     Seven Summit Treks    Switzerland
# 309             Climbing the Seven Summits          Nepal
# 310                         7 Summits Club          Nepal
#
#                    Cause of death                  Location
# No.
# 1                       Avalanche           Below North Col
# 2                       Avalanche           Below North Col
# 3                       Avalanche           Below North Col
# 4                       Avalanche           Below North Col
# 5                       Avalanche           Below North Col
# ..                            ...                       ...
# 306  Cardiac event during descent                 South Col
# 307                    Exhaustion         Near South Summit
# 308                    Exhaustion         Near South Summit
# 309          Fall into a crevasse  Between Camp I & Camp II
# 310                           NaN            near South Col
#
# [310 rows x 7 columns]

# %%
deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 310 entries, 1 to 310
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            310 non-null    object
#  1   Date            310 non-null    object
#  2   Age             160 non-null    float64
#  3   Expedition      271 non-null    object
#  4   Nationality     309 non-null    object
#  5   Cause of death  296 non-null    object
#  6   Location        291 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 19.4+ KB

# %%
zero_nulls = deaths.columns[deaths.isnull().sum()==0]
print(f"The Columns with Zero Null Values: {zero_nulls}")
# Out:
# The Columns with Zero Null Values: Index(['Name', 'Date'], dtype='object')

# %%
null_counts = deaths.isnull().sum()
maximum = null_counts.max()
max_nulls = null_counts[null_counts == maximum].index
print(f"The Columns with Maximum Null Values: {list(max_nulls)} ({maximum} nulls)")
# Out:
# The Columns with Maximum Null Values: ['Age'] (150 nulls)

# %% [markdown]
# ## Part 3
# * Import the `movie_titles.tsv` dataset
# * You'll notice that it is not comma-separated! You'll need to tell `read_csv` what the separator actually is.
# * The dataset does not come with its own column headings, so you'll need to provide those as well.  The columns are, in order, `id`, `title`, `year`, `imdb_rating`, `imdb_id`, and `genres`
# * Once you have successfully read the dataset into a DataFrame, inspect the last 7 rows!

# %%
names = ['id','titles','year','imdb_rating','imdb_id','genres']

# %%
titles = load_dataset('movie_titles.tsv',sep='\t',names=names)

# %%
titles
# Out:
#        id                      titles  year  imdb_rating   imdb_id  \
# 0      m0  10 things i hate about you  1999          6.9   62847.0
# 1      m1  1492: conquest of paradise  1992          6.2   10421.0
# 2      m2                  15 minutes  2001          6.1   25854.0
# 3      m3       2001: a space odyssey  1968          8.4  163227.0
# 4      m4                     48 hrs.  1982          6.9   22289.0
# ..    ...                         ...   ...          ...       ...
# 612  m612                    watchmen  2009          7.8  135229.0
# 613  m613                         xxx  2002          5.6   53505.0
# 614  m614                       x-men  2000          7.4  122149.0
# 615  m615          young frankenstein  1974          8.0   57618.0
# 616  m616                   zulu dawn  1979          6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# 1          ['adventure' 'biography' 'drama' 'history']
# 2                ['action' 'crime' 'drama' 'thriller']
# 3                     ['adventure' 'mystery' 'sci-fi']
# 4       ['action' 'comedy' 'crime' 'drama' 'thriller']
# ..                                                 ...
# 612  ['action' 'crime' 'fantasy' 'mystery' 'sci-fi'...
# 613                     ['action' 'adventure' 'crime']
# 614                                ['action' 'sci-fi']
# 615                                ['comedy' 'sci-fi']
# 616     ['action' 'adventure' 'drama' 'history' 'war']
#
# [617 rows x 6 columns]

# %%
titles.tail(7)
# Out:
#        id                   titles  year  imdb_rating   imdb_id  \
# 610  m610         the wizard of oz  1939          8.3  104873.0
# 611  m611  the world is not enough  1999          6.3   60047.0
# 612  m612                 watchmen  2009          7.8  135229.0
# 613  m613                      xxx  2002          5.6   53505.0
# 614  m614                    x-men  2000          7.4  122149.0
# 615  m615       young frankenstein  1974          8.0   57618.0
# 616  m616                zulu dawn  1979          6.4    1911.0
#
#                                                 genres
# 610         ['adventure' 'family' 'fantasy' 'musical']
# 611                  ['action' 'adventure' 'thriller']
# 612  ['action' 'crime' 'fantasy' 'mystery' 'sci-fi'...
# 613                     ['action' 'adventure' 'crime']
# 614                                ['action' 'sci-fi']
# 615                                ['comedy' 'sci-fi']
# 616     ['action' 'adventure' 'drama' 'history' 'war']
